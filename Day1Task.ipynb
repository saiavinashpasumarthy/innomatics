# %% [markdown]
# <a href="https://colab.research.google.com/github/saiavinashpasumarthy/innomatics/blob/main/Day1Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Validusername= "admin"
Validpassword="1234"

username=input("enter username:")
password=input("enter password:")

if Validusername==username and Validpassword==password:
  print("Login Successful")
else:
  print("Invalid credentials")
# Out:
# enter username:admin
# enter password1234
# Login Successful

# %%
marks=[45,78,90,33,60]
passed = 0
fail = 0
for mark in marks:
  if mark >=50:
    passed += 1
  else:
    fail += 1
print("passed =", passed)
print("failed=", fail)
# Out:
# passed = 3
# failed= 2

# %%
names = [" Alice ", "bob", " CHARLIE "]
cleaned_data=[]
for name in names:
  cleaned= name.strip().lower()
  cleaned_data.append(cleaned)
print("original names =",names)
print("cleaned names =",cleaned_data)
# Out:
# original names = [' Alice ', 'bob', ' CHARLIE ']
# cleaned names = ['alice', 'bob', 'charlie']

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for message in messages:
  print(message, "=",len(message))
  if len(message)>10:
    print("Status:flagged")
  else:
    print("status: within limit")
  print()
# Out:
# Hi = 2
# status: within limit
#
# Welcome to the platform = 23
# Status:flagged
#
# OK = 2
# status: within limit

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
count= logs.count("ERROR")
print("Total ERROR Count=",count)
# Out:
# Total ERROR Count= 2
